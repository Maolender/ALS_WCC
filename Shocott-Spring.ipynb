# %%
# importing all the modules 

import sys
import math
import laspy
import pyproj

import numpy as np
import pandas as pd
import geopandas as gpd

from datetime import datetime
from pycrown import PyCrown
from shapely.geometry import Polygon

# %%
# Define the input folder where the files are stored
input_folder = 'input'

# Paths to the input files including DSM, DTM, CHM, and LiDAR point cloud,
# already clipped to the study site extent.
F_CHM = f'{input_folder}/clipped_CHM.tif'
F_DTM = f'{input_folder}/clipped_DTM.tif'
F_DSM = f'{input_folder}/clipped_DSM.tif'
F_LAS = f'{input_folder}/clipped_pointcloud.las'

# %%
# Initialize the PyCrown class with the provided input files
# F_CHM: Path to the Canopy Height Model (CHM) file in .tif format
# F_DTM: Path to the Digital Terrain Model (DTM) file in .tif format
# F_DSM: Path to the Digital Surface Model (DSM) file in .tif format
# F_LAS: Path to the LiDAR point cloud file in .las format
# outpath: The directory where the output results will be saved
PC = PyCrown(F_CHM, F_DTM, F_DSM, F_LAS, outpath='result')

# %%
# Smoothing of CHM while preserving fine details in the CHM
# The method filter_chm applies a smoothing filter to the Canopy Height Model (CHM).
# Parameters:
# 1: The window size in pixels for smoothing. A value of 1 means no smoothing is applied,
#    as each pixel is considered individually without averaging neighboring values.

# ws_in_pixels=True: Specifies that the window size is given in pixels, not in some other unit.
# circular=False: Indicates that a square window is used for filtering instead of a circular one.

PC.filter_chm(1, ws_in_pixels=True, circular=False)

# %%
# Tree detection in the CHM using specified parameters
# The method tree_detection identifies tree tops in the Canopy Height Model (CHM).
# Parameters:
# PC.chm: The Canopy Height Model to be analyzed.
# ws=1: A window size of 1x1 pixel, meaning each pixel is considered independently as a potential tree top.
# hmin=1.3: The minimum height threshold for a pixel to be considered as a tree top. 
#   This has been adjusted from 16.0 to 1.3 meters to detect smaller trees.

PC.tree_detection(PC.chm, ws=1, hmin=1.3)

# %%
# Delineation of tree crowns using the specified algorithm and thresholds
# The method crown_delineation is used to define the boundaries of tree crowns in the CHM.

# Define parameters for crown delineation
algorithm = 'dalponteCIRC_numba'  # Algorithm used for crown delineation
th_tree = 1.3  # Minimum height threshold for considering a tree crown in meters
th_seed = 0.5  # Seed threshold factor
th_crown = 0.05  # Crown threshold factor
max_crown = 4.0  # Maximum allowable crown radius in meters

# Delineation of tree crowns using the specified algorithm and thresholds
PC.crown_delineation(algorithm=algorithm,
                     th_tree=th_tree,
                     th_seed=th_seed,
                     th_crown=th_crown,
                     max_crown=max_crown)
# Out:
# Tree crowns delineation: 0.004s

# %%
# Correcting tree tops after initial detection
# The correct_tree_tops() function refines the positions of detected tree tops.
# This process includes:
# - Removing false positives: tree tops that were incorrectly identified due to noise or low thresholds.
# - Adjusting the position of tree tops to more accurate locations within the tree crowns.
# - Merging closely positioned tree tops that likely represent the same tree.

# This correction step ensures that the final tree top positions are more accurate, 
# leading to better results in subsequent analyses.
PC.correct_tree_tops()
# Out:
# Number of trees: 6021
# Tree tops corrected: 2551
# Tree tops corrected: 42.36837734595582%
# DSM correction: 475
# COM correction: 2076
# (475, 2076)

# %%
# Calculate tree height and elevation for the detected tree tops
PC.get_tree_height_elevation(loc='top')

# Calculate tree height and elevation for the corrected tree tops
PC.get_tree_height_elevation(loc='top_cor')

# %%
# Screen out small trees from the detected tree tops
# hmin=0.2: Minimum height threshold for a tree is 0.2 meters.
PC.screen_small_trees(hmin=0.2, loc='top')

# %%
# Convert detected tree crowns to polygon shapes using a raster-based approach
PC.crowns_to_polys_raster()

# Convert detected tree crowns to smoothed polygon shapes
# and optionally store the corresponding LiDAR points for each crown
PC.crowns_to_polys_smooth(store_las=True)
# Out:
# Converting LAS point cloud to shapely points
# Converting raster crowns to shapely polygons
# Attach LiDAR points to corresponding crowns
# Create convex hull around first return points
# Classifying point cloud

# %%
# Perform quality control on the detected and processed tree crowns
PC.quality_control()

# %%
print(f"Number of trees detected: {len(PC.trees)}")
# Out:
# Number of trees detected: 6021

# %%
# Export the Canopy Height Model (CHM) as a raster file
PC.export_raster(PC.chm, PC.outpath / 'chm.tif', 'CHM')

# Export the locations of the initially detected tree tops
PC.export_tree_locations(loc='top')

# Export the locations of the corrected tree tops
PC.export_tree_locations(loc='top_cor')

# Export the tree crowns as raster-based polygons
PC.export_tree_crowns(crowntype='crown_poly_raster')

# Export the tree crowns as smoothed polygons
PC.export_tree_crowns(crowntype='crown_poly_smooth')
# Out:
# Exported 6021 valid tree crowns to result/tree_crown_poly_raster.shp
# Skipping unsupported geometry type at index 3
# Skipping unsupported geometry type at index 5
# Skipping unsupported geometry type at index 6
# Skipping unsupported geometry type at index 7
# Skipping unsupported geometry type at index 11
# Skipping unsupported geometry type at index 12
# Skipping unsupported geometry type at index 13
# Skipping unsupported geometry type at index 14
# Skipping LineString with insufficient points at index 15
# Skipping unsupported geometry type at index 16
# Skipping unsupported geometry type at index 18
# Skipping unsupported geometry type at index 19
# Skipping unsupported geometry type at index 20
# Skipping unsupported geometry type at index 21
# Skipping unsupported geometry type at index 22
# Skipping unsupported geometry type at index 23
# Skipping unsupported geometry type at index 24
# Skipping unsupported geometry type at index 25
# Skipping unsupported geometry type at index 26
# Skipping unsupported geometry type at index 27
# Skipping unsupported geometry type at index 28
# Skipping unsupported geometry type at index 29
# Skipping unsupported geometry type at index 30
# Skipping unsupported geometry type at index 31
# Skipping LineString with insufficient points at index 32
# Skipping LineString with insufficient points at index 35
# Skipping LineString with insufficient points at index 36
# Skipping LineString with insufficient points at index 37
# Skipping unsupported geometry type at index 38
# Skipping unsupported geometry type at index 39
# Skipping LineString with insufficient points at index 40
# Skipping unsupported geometry type at index 42
# Skipping unsupported geometry type at index 43
# Skipping LineString with insufficient points at index 44
# Skipping unsupported geometry type at index 45
# Skipping unsupported geometry type at index 48
# Skipping unsupported geometry type at index 49
# Skipping unsupported geometry type at index 50
# Skipping unsupported geometry type at index 51
# Skipping unsupported geometry type at index 52
# Skipping unsupported geometry type at index 55
# Skipping LineString with insufficient points at index 56
# Skipping LineString with insufficient points at index 60
# Skipping LineString with insufficient points at index 62
# Skipping unsupported geometry type at index 63
# Skipping LineString with insufficient points at index 64
# Skipping unsupported geometry type at index 65
# Skipping LineString with insufficient points at index 66
# Skipping LineString with insufficient points at index 67
# Skipping unsupported geometry type at index 68
# Skipping unsupported geometry type at index 70
# Skipping unsupported geometry type at index 71
# Skipping unsupported geometry type at index 72
# Skipping unsupported geometry type at index 73
# Skipping LineString with insufficient points at index 75
# Skipping LineString with insufficient points at index 76
# Skipping unsupported geometry type at index 77
# Skipping unsupported geometry type at index 78
# Skipping unsupported geometry type at index 80
# Skipping LineString with insufficient points at index 81
# Skipping LineString with insufficient points at index 82
# Skipping unsupported geometry type at index 83
# Skipping LineString with insufficient points at index 86
# Skipping unsupported geometry type at index 88
# Skipping unsupported geometry type at index 90
# Skipping unsupported geometry type at index 91
# Skipping LineString with insufficient points at index 92
# Skipping unsupported geometry type at index 94
# Skipping unsupported geometry type at index 95
# Skipping LineString with insufficient points at index 96
# Skipping unsupported geometry type at index 97
# Skipping unsupported geometry type at index 98
# Skipping unsupported geometry type at index 99
# Skipping LineString with insufficient points at index 100
# Skipping unsupported geometry type at index 101
# Skipping unsupported geometry type at index 102
# Skipping unsupported geometry type at index 103
# Skipping unsupported geometry type at index 104
# Skipping LineString with insufficient points at index 105
# Skipping LineString with insufficient points at index 106
# Skipping LineString with insufficient points at index 107
# Skipping LineString with insufficient points at index 108
# Skipping LineString with insufficient points at index 109
# Skipping unsupported geometry type at index 112
# Skipping unsupported geometry type at index 113
# Skipping unsupported geometry type at index 115
# Skipping unsupported geometry type at index 116
# Skipping unsupported geometry type at index 117
# Skipping unsupported geometry type at index 118
# Skipping unsupported geometry type at index 119
# Skipping LineString with insufficient points at index 120
# Skipping LineString with insufficient points at index 122
# Skipping unsupported geometry type at index 123
# Skipping unsupported geometry type at index 124
# Skipping LineString with insufficient points at index 126
# Skipping unsupported geometry type at index 127
# Skipping LineString with insufficient points at index 128
# Skipping LineString with insufficient points at index 129
# Skipping unsupported geometry type at index 130
# Skipping unsupported geometry type at index 131
# Skipping unsupported geometry type at index 132
# Skipping unsupported geometry type at index 133
# Skipping unsupported geometry type at index 134
# Skipping LineString with insufficient points at index 135
# Skipping unsupported geometry type at index 136
# Skipping unsupported geometry type at index 137
# Skipping LineString with insufficient points at index 138
# Skipping unsupported geometry type at index 139
# Skipping unsupported geometry type at index 140
# Skipping unsupported geometry type at index 141
# Skipping unsupported geometry type at index 142
# Skipping LineString with insufficient points at index 143
# Skipping unsupported geometry type at index 144
# Skipping LineString with insufficient points at index 145
# Skipping unsupported geometry type at index 146
# Skipping LineString with insufficient points at index 147
# Skipping LineString with insufficient points at index 149
# Skipping unsupported geometry type at index 150
# Skipping unsupported geometry type at index 151
# Skipping unsupported geometry type at index 152
# Skipping unsupported geometry type at index 156
# Skipping LineString with insufficient points at index 165
# Skipping LineString with insufficient points at index 175
# Skipping LineString with insufficient points at index 176
# Skipping unsupported geometry type at index 194
# Skipping LineString with insufficient points at index 200
# Skipping LineString with insufficient points at index 214
# Skipping LineString with insufficient points at index 216
# Skipping unsupported geometry type at index 220
# Skipping LineString with insufficient points at index 224
# Skipping LineString with insufficient points at index 231
# Skipping unsupported geometry type at index 232
# Skipping LineString with insufficient points at index 239
# Skipping unsupported geometry type at index 250
# Skipping LineString with insufficient points at index 251
# Skipping unsupported geometry type at index 254
# Skipping unsupported geometry type at index 255
# Skipping LineString with insufficient points at index 265
# Skipping unsupported geometry type at index 268
# Skipping LineString with insufficient points at index 269
# Skipping unsupported geometry type at index 274
# Skipping unsupported geometry type at index 281
# Skipping LineString with insufficient points at index 282
# Skipping unsupported geometry type at index 286
# Skipping unsupported geometry type at index 287
# Skipping unsupported geometry type at index 305
# Skipping unsupported geometry type at index 306
# Skipping LineString with insufficient points at index 313
# Skipping unsupported geometry type at index 314
# Skipping unsupported geometry type at index 317
# Skipping unsupported geometry type at index 318
# Skipping LineString with insufficient points at index 322
# Skipping unsupported geometry type at index 324
# Skipping LineString with insufficient points at index 326
# Skipping LineString with insufficient points at index 327
# Skipping LineString with insufficient points at index 333
# Skipping unsupported geometry type at index 336
# Skipping unsupported geometry type at index 341
# Skipping LineString with insufficient points at index 350
# Skipping LineString with insufficient points at index 354
# Skipping LineString with insufficient points at index 357
# Skipping unsupported geometry type at index 361
# Skipping LineString with insufficient points at index 372
# Skipping unsupported geometry type at index 373
# Skipping LineString with insufficient points at index 383
# Skipping unsupported geometry type at index 385
# Skipping unsupported geometry type at index 390
# Skipping LineString with insufficient points at index 391
# Skipping unsupported geometry type at index 392
# Skipping LineString with insufficient points at index 402
# Skipping unsupported geometry type at index 403
# Skipping unsupported geometry type at index 405
# Skipping LineString with insufficient points at index 406
# Skipping unsupported geometry type at index 409
# Skipping unsupported geometry type at index 414
# Skipping LineString with insufficient points at index 415
# Skipping unsupported geometry type at index 418
# Skipping LineString with insufficient points at index 421
# Skipping LineString with insufficient points at index 425
# Skipping unsupported geometry type at index 427
# Skipping unsupported geometry type at index 438
# Skipping unsupported geometry type at index 440
# Skipping unsupported geometry type at index 441
# Skipping LineString with insufficient points at index 442
# Skipping unsupported geometry type at index 444
# Skipping LineString with insufficient points at index 445
# Skipping unsupported geometry type at index 450
# Skipping unsupported geometry type at index 460
# Skipping unsupported geometry type at index 464
# Skipping unsupported geometry type at index 467
# Skipping unsupported geometry type at index 468
# Skipping unsupported geometry type at index 485
# Skipping LineString with insufficient points at index 494
# Skipping LineString with insufficient points at index 502
# Skipping LineString with insufficient points at index 504
# Skipping unsupported geometry type at index 507
# Skipping LineString with insufficient points at index 508
# Skipping LineString with insufficient points at index 510
# Skipping unsupported geometry type at index 512
# Skipping unsupported geometry type at index 513
# Skipping LineString with insufficient points at index 514
# Skipping unsupported geometry type at index 532
# Skipping LineString with insufficient points at index 548
# Skipping unsupported geometry type at index 561
# Skipping LineString with insufficient points at index 572
# Skipping unsupported geometry type at index 579
# Skipping unsupported geometry type at index 582
# Skipping LineString with insufficient points at index 585
# Skipping unsupported geometry type at index 590
# Skipping unsupported geometry type at index 592
# Skipping unsupported geometry type at index 598
# Skipping LineString with insufficient points at index 600
# Skipping unsupported geometry type at index 601
# Skipping LineString with insufficient points at index 602
# Skipping unsupported geometry type at index 605
# Skipping LineString with insufficient points at index 612
# Skipping LineString with insufficient points at index 613
# Skipping LineString with insufficient points at index 614
# Skipping LineString with insufficient points at index 616
# Skipping LineString with insufficient points at index 621
# Skipping unsupported geometry type at index 626
# Skipping unsupported geometry type at index 631
# Skipping unsupported geometry type at index 634
# Skipping unsupported geometry type at index 642
# Skipping unsupported geometry type at index 643
# Skipping unsupported geometry type at index 646
# Skipping unsupported geometry type at index 647
# Skipping LineString with insufficient points at index 649
# Skipping LineString with insufficient points at index 654
# Skipping LineString with insufficient points at index 655
# Skipping unsupported geometry type at index 657
# Skipping LineString with insufficient points at index 658
# Skipping unsupported geometry type at index 661
# Skipping LineString with insufficient points at index 662
# Skipping LineString with insufficient points at index 663
# Skipping LineString with insufficient points at index 669
# Skipping LineString with insufficient points at index 670
# Skipping LineString with insufficient points at index 681
# Skipping LineString with insufficient points at index 686
# Skipping unsupported geometry type at index 700
# Skipping LineString with insufficient points at index 701
# Skipping LineString with insufficient points at index 708
# Skipping LineString with insufficient points at index 713
# Skipping unsupported geometry type at index 726
# Skipping unsupported geometry type at index 728
# Skipping LineString with insufficient points at index 729
# Skipping unsupported geometry type at index 734
# Skipping unsupported geometry type at index 749
# Skipping unsupported geometry type at index 751
# Skipping unsupported geometry type at index 752
# Skipping LineString with insufficient points at index 754
# Skipping LineString with insufficient points at index 768
# Skipping unsupported geometry type at index 776
# Skipping LineString with insufficient points at index 782
# Skipping LineString with insufficient points at index 788
# Skipping unsupported geometry type at index 801
# Skipping unsupported geometry type at index 822
# Skipping unsupported geometry type at index 827
# Skipping LineString with insufficient points at index 832
# Skipping LineString with insufficient points at index 837
# Skipping unsupported geometry type at index 838
# Skipping unsupported geometry type at index 839
# Skipping unsupported geometry type at index 840
# Skipping LineString with insufficient points at index 843
# Skipping LineString with insufficient points at index 873
# Skipping unsupported geometry type at index 875
# Skipping LineString with insufficient points at index 878
# Skipping LineString with insufficient points at index 885
# Skipping LineString with insufficient points at index 886
# Skipping unsupported geometry type at index 887
# Skipping LineString with insufficient points at index 896
# Skipping LineString with insufficient points at index 897
# Skipping LineString with insufficient points at index 899
# Skipping LineString with insufficient points at index 901
# Skipping unsupported geometry type at index 908
# Skipping unsupported geometry type at index 916
# Skipping unsupported geometry type at index 918
# Skipping LineString with insufficient points at index 923
# Skipping unsupported geometry type at index 927
# Skipping LineString with insufficient points at index 933
# Skipping unsupported geometry type at index 934
# Skipping LineString with insufficient points at index 937
# Skipping LineString with insufficient points at index 939
# Skipping unsupported geometry type at index 943
# Skipping LineString with insufficient points at index 945
# Skipping LineString with insufficient points at index 953
# Skipping unsupported geometry type at index 961
# Skipping LineString with insufficient points at index 974
# Skipping unsupported geometry type at index 977
# Skipping unsupported geometry type at index 979
# Skipping unsupported geometry type at index 982
# Skipping LineString with insufficient points at index 984
# Skipping LineString with insufficient points at index 991
# Skipping LineString with insufficient points at index 994
# Skipping unsupported geometry type at index 995
# Skipping LineString with insufficient points at index 999
# Skipping unsupported geometry type at index 1002
# Skipping unsupported geometry type at index 1007
# Skipping LineString with insufficient points at index 1008
# Skipping LineString with insufficient points at index 1009
# Skipping unsupported geometry type at index 1012
# Skipping unsupported geometry type at index 1019
# Skipping unsupported geometry type at index 1020
# Skipping unsupported geometry type at index 1023
# Skipping unsupported geometry type at index 1024
# Skipping unsupported geometry type at index 1026
# Skipping unsupported geometry type at index 1027
# Skipping unsupported geometry type at index 1028
# Skipping unsupported geometry type at index 1031
# Skipping LineString with insufficient points at index 1032
# Skipping unsupported geometry type at index 1036
# Skipping unsupported geometry type at index 1039
# Skipping LineString with insufficient points at index 1040
# Skipping unsupported geometry type at index 1041
# Skipping unsupported geometry type at index 1046
# Skipping unsupported geometry type at index 1047
# Skipping LineString with insufficient points at index 1050
# Skipping LineString with insufficient points at index 1057
# Skipping LineString with insufficient points at index 1058
# Skipping unsupported geometry type at index 1059
# Skipping unsupported geometry type at index 1064
# Skipping LineString with insufficient points at index 1075
# Skipping unsupported geometry type at index 1077
# Skipping unsupported geometry type at index 1083
# Skipping unsupported geometry type at index 1097
# Skipping unsupported geometry type at index 1099
# Skipping unsupported geometry type at index 1102
# Skipping LineString with insufficient points at index 1105
# Skipping LineString with insufficient points at index 1115
# Skipping unsupported geometry type at index 1117
# Skipping LineString with insufficient points at index 1119
# Skipping LineString with insufficient points at index 1125
# Skipping LineString with insufficient points at index 1127
# Skipping unsupported geometry type at index 1128
# Skipping unsupported geometry type at index 1135
# Skipping LineString with insufficient points at index 1138
# Skipping unsupported geometry type at index 1146
# Skipping LineString with insufficient points at index 1147
# Skipping LineString with insufficient points at index 1149
# Skipping unsupported geometry type at index 1159
# Skipping unsupported geometry type at index 1163
# Skipping LineString with insufficient points at index 1166
# Skipping LineString with insufficient points at index 1167
# Skipping unsupported geometry type at index 1168
# Skipping unsupported geometry type at index 1169
# Skipping LineString with insufficient points at index 1172
# Skipping unsupported geometry type at index 1173
# Skipping LineString with insufficient points at index 1178
# Skipping LineString with insufficient points at index 1179
# Skipping unsupported geometry type at index 1185
# Skipping LineString with insufficient points at index 1188
# Skipping LineString with insufficient points at index 1189
# Skipping LineString with insufficient points at index 1202
# Skipping unsupported geometry type at index 1206
# Skipping LineString with insufficient points at index 1221
# Skipping unsupported geometry type at index 1222
# Skipping unsupported geometry type at index 1233
# Skipping unsupported geometry type at index 1234
# Skipping LineString with insufficient points at index 1235
# Skipping unsupported geometry type at index 1248
# Skipping unsupported geometry type at index 1251
# Skipping LineString with insufficient points at index 1254
# Skipping LineString with insufficient points at index 1258
# Skipping unsupported geometry type at index 1260
# Skipping LineString with insufficient points at index 1264
# Skipping LineString with insufficient points at index 1266
# Skipping LineString with insufficient points at index 1268
# Skipping unsupported geometry type at index 1274
# Skipping unsupported geometry type at index 1275
# Skipping unsupported geometry type at index 1276
# Skipping unsupported geometry type at index 1277
# Skipping LineString with insufficient points at index 1285
# Skipping unsupported geometry type at index 1286
# Skipping unsupported geometry type at index 1294
# Skipping unsupported geometry type at index 1295
# Skipping LineString with insufficient points at index 1304
# Skipping unsupported geometry type at index 1309
# Skipping unsupported geometry type at index 1318
# Skipping LineString with insufficient points at index 1321
# Skipping LineString with insufficient points at index 1324
# Skipping LineString with insufficient points at index 1325
# Skipping LineString with insufficient points at index 1330
# Skipping unsupported geometry type at index 1331
# Skipping LineString with insufficient points at index 1334
# Skipping unsupported geometry type at index 1336
# Skipping unsupported geometry type at index 1337
# Skipping LineString with insufficient points at index 1347
# Skipping LineString with insufficient points at index 1350
# Skipping unsupported geometry type at index 1354
# Skipping LineString with insufficient points at index 1355
# Skipping LineString with insufficient points at index 1360
# Skipping LineString with insufficient points at index 1361
# Skipping unsupported geometry type at index 1363
# Skipping unsupported geometry type at index 1364
# Skipping LineString with insufficient points at index 1366
# Skipping unsupported geometry type at index 1370
# Skipping unsupported geometry type at index 1372
# Skipping unsupported geometry type at index 1374
# Skipping unsupported geometry type at index 1376
# Skipping LineString with insufficient points at index 1379
# Skipping unsupported geometry type at index 1386
# Skipping unsupported geometry type at index 1391
# Skipping unsupported geometry type at index 1393
# Skipping unsupported geometry type at index 1395
# Skipping LineString with insufficient points at index 1401
# Skipping LineString with insufficient points at index 1402
# Skipping unsupported geometry type at index 1403
# Skipping LineString with insufficient points at index 1417
# Skipping unsupported geometry type at index 1426
# Skipping LineString with insufficient points at index 1428
# Skipping unsupported geometry type at index 1431
# Skipping LineString with insufficient points at index 1435
# Skipping LineString with insufficient points at index 1436
# Skipping LineString with insufficient points at index 1439
# Skipping unsupported geometry type at index 1454
# Skipping unsupported geometry type at index 1457
# Skipping LineString with insufficient points at index 1462
# Skipping unsupported geometry type at index 1464
# Skipping LineString with insufficient points at index 1468
# Skipping unsupported geometry type at index 1469
# Skipping LineString with insufficient points at index 1478
# Skipping unsupported geometry type at index 1481
# Skipping unsupported geometry type at index 1483
# Skipping LineString with insufficient points at index 1484
# Skipping unsupported geometry type at index 1490
# Skipping unsupported geometry type at index 1501
# Skipping unsupported geometry type at index 1503
# Skipping unsupported geometry type at index 1506
# Skipping LineString with insufficient points at index 1510
# Skipping LineString with insufficient points at index 1515
# Skipping unsupported geometry type at index 1518
# Skipping LineString with insufficient points at index 1520
# Skipping unsupported geometry type at index 1523
# Skipping unsupported geometry type at index 1525
# Skipping unsupported geometry type at index 1526
# Skipping unsupported geometry type at index 1528
# Skipping LineString with insufficient points at index 1529
# Skipping LineString with insufficient points at index 1530
# Skipping LineString with insufficient points at index 1534
# Skipping LineString with insufficient points at index 1545
# Skipping LineString with insufficient points at index 1546
# Skipping LineString with insufficient points at index 1548
# Skipping unsupported geometry type at index 1549
# Skipping LineString with insufficient points at index 1553
# Skipping unsupported geometry type at index 1556
# Skipping LineString with insufficient points at index 1563
# Skipping unsupported geometry type at index 1565
# Skipping unsupported geometry type at index 1566
# Skipping LineString with insufficient points at index 1569
# Skipping LineString with insufficient points at index 1575
# Skipping LineString with insufficient points at index 1577
# Skipping unsupported geometry type at index 1589
# Skipping LineString with insufficient points at index 1594
# Skipping LineString with insufficient points at index 1595
# Skipping unsupported geometry type at index 1596
# Skipping LineString with insufficient points at index 1601
# Skipping unsupported geometry type at index 1603
# Skipping unsupported geometry type at index 1607
# Skipping unsupported geometry type at index 1608
# Skipping unsupported geometry type at index 1616
# Skipping LineString with insufficient points at index 1619
# Skipping LineString with insufficient points at index 1622
# Skipping LineString with insufficient points at index 1624
# Skipping LineString with insufficient points at index 1628
# Skipping LineString with insufficient points at index 1631
# Skipping unsupported geometry type at index 1632
# Skipping LineString with insufficient points at index 1633
# Skipping unsupported geometry type at index 1636
# Skipping LineString with insufficient points at index 1637
# Skipping unsupported geometry type at index 1639
# Skipping LineString with insufficient points at index 1640
# Skipping LineString with insufficient points at index 1644
# Skipping LineString with insufficient points at index 1647
# Skipping unsupported geometry type at index 1652
# Skipping unsupported geometry type at index 1653
# Skipping unsupported geometry type at index 1656
# Skipping unsupported geometry type at index 1658
# Skipping LineString with insufficient points at index 1665
# Skipping LineString with insufficient points at index 1666
# Skipping LineString with insufficient points at index 1670
# Skipping LineString with insufficient points at index 1681
# Skipping LineString with insufficient points at index 1682
# Skipping unsupported geometry type at index 1683
# Skipping unsupported geometry type at index 1685
# Skipping unsupported geometry type at index 1691
# Skipping LineString with insufficient points at index 1692
# Skipping LineString with insufficient points at index 1693
# Skipping LineString with insufficient points at index 1697
# Skipping LineString with insufficient points at index 1704
# Skipping unsupported geometry type at index 1707
# Skipping LineString with insufficient points at index 1712
# Skipping unsupported geometry type at index 1715
# Skipping LineString with insufficient points at index 1717
# Skipping unsupported geometry type at index 1728
# Skipping LineString with insufficient points at index 1736
# Skipping LineString with insufficient points at index 1737
# Skipping unsupported geometry type at index 1741
# Skipping LineString with insufficient points at index 1742
# Skipping LineString with insufficient points at index 1744
# Skipping LineString with insufficient points at index 1745
# Skipping LineString with insufficient points at index 1747
# Skipping unsupported geometry type at index 1748
# Skipping LineString with insufficient points at index 1750
# Skipping LineString with insufficient points at index 1756
# Skipping unsupported geometry type at index 1757
# Skipping LineString with insufficient points at index 1758
# Skipping LineString with insufficient points at index 1762
# Skipping unsupported geometry type at index 1772
# Skipping unsupported geometry type at index 1776
# Skipping LineString with insufficient points at index 1792
# Skipping LineString with insufficient points at index 1794
# Skipping LineString with insufficient points at index 1796
# Skipping unsupported geometry type at index 1799
# Skipping unsupported geometry type at index 1802
# Skipping unsupported geometry type at index 1805
# Skipping unsupported geometry type at index 1807
# Skipping unsupported geometry type at index 1810
# Skipping unsupported geometry type at index 1813
# Skipping LineString with insufficient points at index 1818
# Skipping unsupported geometry type at index 1822
# Skipping unsupported geometry type at index 1826
# Skipping LineString with insufficient points at index 1829
# Skipping LineString with insufficient points at index 1831
# Skipping LineString with insufficient points at index 1833
# Skipping unsupported geometry type at index 1835
# Skipping unsupported geometry type at index 1841
# Skipping LineString with insufficient points at index 1845
# Skipping LineString with insufficient points at index 1848
# Skipping unsupported geometry type at index 1850
# Skipping unsupported geometry type at index 1861
# Skipping unsupported geometry type at index 1874
# Skipping unsupported geometry type at index 1878
# Skipping LineString with insufficient points at index 1889
# Skipping unsupported geometry type at index 1890
# Skipping unsupported geometry type at index 1893
# Skipping unsupported geometry type at index 1897
# Skipping LineString with insufficient points at index 1901
# Skipping unsupported geometry type at index 1912
# Skipping LineString with insufficient points at index 1919
# Skipping unsupported geometry type at index 1920
# Skipping LineString with insufficient points at index 1924
# Skipping unsupported geometry type at index 1928
# Skipping unsupported geometry type at index 1930
# Skipping LineString with insufficient points at index 1934
# Skipping LineString with insufficient points at index 1941
# Skipping LineString with insufficient points at index 1942
# Skipping LineString with insufficient points at index 1943
# Skipping unsupported geometry type at index 1944
# Skipping LineString with insufficient points at index 1950
# Skipping LineString with insufficient points at index 1951
# Skipping LineString with insufficient points at index 1955
# Skipping LineString with insufficient points at index 1957
# Skipping LineString with insufficient points at index 1959
# Skipping unsupported geometry type at index 1960
# Skipping LineString with insufficient points at index 1961
# Skipping unsupported geometry type at index 1966
# Skipping LineString with insufficient points at index 1968
# Skipping unsupported geometry type at index 1971
# Skipping unsupported geometry type at index 1977
# Skipping LineString with insufficient points at index 1985
# Skipping unsupported geometry type at index 1992
# Skipping LineString with insufficient points at index 2002
# Skipping LineString with insufficient points at index 2003
# Skipping unsupported geometry type at index 2006
# Skipping unsupported geometry type at index 2011
# Skipping LineString with insufficient points at index 2012
# Skipping unsupported geometry type at index 2014
# Skipping LineString with insufficient points at index 2021
# Skipping LineString with insufficient points at index 2022
# Skipping LineString with insufficient points at index 2029
# Skipping unsupported geometry type at index 2035
# Skipping unsupported geometry type at index 2037
# Skipping LineString with insufficient points at index 2038
# Skipping LineString with insufficient points at index 2045
# Skipping LineString with insufficient points at index 2047
# Skipping unsupported geometry type at index 2051
# Skipping LineString with insufficient points at index 2054
# Skipping unsupported geometry type at index 2056
# Skipping unsupported geometry type at index 2059
# Skipping LineString with insufficient points at index 2061
# Skipping LineString with insufficient points at index 2062
# Skipping unsupported geometry type at index 2063
# Skipping LineString with insufficient points at index 2067
# Skipping unsupported geometry type at index 2069
# Skipping unsupported geometry type at index 2070
# Skipping unsupported geometry type at index 2073
# Skipping unsupported geometry type at index 2077
# Skipping unsupported geometry type at index 2086
# Skipping unsupported geometry type at index 2093
# Skipping LineString with insufficient points at index 2094
# Skipping LineString with insufficient points at index 2097
# Skipping unsupported geometry type at index 2099
# Skipping unsupported geometry type at index 2102
# Skipping LineString with insufficient points at index 2108
# Skipping unsupported geometry type at index 2111
# Skipping unsupported geometry type at index 2112
# Skipping LineString with insufficient points at index 2115
# Skipping LineString with insufficient points at index 2119
# Skipping unsupported geometry type at index 2134
# Skipping unsupported geometry type at index 2135
# Skipping LineString with insufficient points at index 2136
# Skipping unsupported geometry type at index 2141
# Skipping unsupported geometry type at index 2142
# Skipping unsupported geometry type at index 2145
# Skipping LineString with insufficient points at index 2149
# Skipping unsupported geometry type at index 2150
# Skipping unsupported geometry type at index 2153
# Skipping LineString with insufficient points at index 2154
# Skipping unsupported geometry type at index 2155
# Skipping LineString with insufficient points at index 2157
# Skipping unsupported geometry type at index 2159
# Skipping unsupported geometry type at index 2160
# Skipping LineString with insufficient points at index 2161
# Skipping LineString with insufficient points at index 2166
# Skipping LineString with insufficient points at index 2178
# Skipping LineString with insufficient points at index 2185
# Skipping unsupported geometry type at index 2188
# Skipping unsupported geometry type at index 2190
# Skipping LineString with insufficient points at index 2192
# Skipping unsupported geometry type at index 2197
# Skipping unsupported geometry type at index 2198
# Skipping unsupported geometry type at index 2199
# Skipping unsupported geometry type at index 2201
# Skipping unsupported geometry type at index 2210
# Skipping unsupported geometry type at index 2219
# Skipping unsupported geometry type at index 2229
# Skipping LineString with insufficient points at index 2233
# Skipping LineString with insufficient points at index 2234
# Skipping LineString with insufficient points at index 2239
# Skipping unsupported geometry type at index 2243
# Skipping LineString with insufficient points at index 2250
# Skipping unsupported geometry type at index 2255
# Skipping unsupported geometry type at index 2257
# Skipping unsupported geometry type at index 2258
# Skipping unsupported geometry type at index 2268
# Skipping LineString with insufficient points at index 2270
# Skipping unsupported geometry type at index 2280
# Skipping LineString with insufficient points at index 2291
# Skipping LineString with insufficient points at index 2293
# Skipping unsupported geometry type at index 2297
# Skipping LineString with insufficient points at index 2305
# Skipping unsupported geometry type at index 2306
# Skipping unsupported geometry type at index 2316
# Skipping unsupported geometry type at index 2323
# Skipping LineString with insufficient points at index 2346
# Skipping LineString with insufficient points at index 2348
# Skipping LineString with insufficient points at index 2351
# Skipping unsupported geometry type at index 2352
# Skipping LineString with insufficient points at index 2353
# Skipping LineString with insufficient points at index 2354
# Skipping unsupported geometry type at index 2359
# Skipping LineString with insufficient points at index 2362
# Skipping unsupported geometry type at index 2363
# Skipping LineString with insufficient points at index 2372
# Skipping LineString with insufficient points at index 2374
# Skipping LineString with insufficient points at index 2378
# Skipping unsupported geometry type at index 2382
# Skipping LineString with insufficient points at index 2383
# Skipping unsupported geometry type at index 2384
# Skipping LineString with insufficient points at index 2395
# Skipping unsupported geometry type at index 2398
# Skipping unsupported geometry type at index 2399
# Skipping LineString with insufficient points at index 2400
# Skipping LineString with insufficient points at index 2423
# Skipping unsupported geometry type at index 2424
# Skipping unsupported geometry type at index 2433
# Skipping unsupported geometry type at index 2434
# Skipping unsupported geometry type at index 2435
# Skipping unsupported geometry type at index 2436
# Skipping LineString with insufficient points at index 2437
# Skipping unsupported geometry type at index 2440
# Skipping unsupported geometry type at index 2441
# Skipping LineString with insufficient points at index 2444
# Skipping LineString with insufficient points at index 2450
# Skipping LineString with insufficient points at index 2451
# Skipping unsupported geometry type at index 2452
# Skipping LineString with insufficient points at index 2461
# Skipping unsupported geometry type at index 2469
# Skipping LineString with insufficient points at index 2481
# Skipping LineString with insufficient points at index 2482
# Skipping LineString with insufficient points at index 2484
# Skipping LineString with insufficient points at index 2489
# Skipping unsupported geometry type at index 2494
# Skipping LineString with insufficient points at index 2498
# Skipping LineString with insufficient points at index 2499
# Skipping LineString with insufficient points at index 2500
# Skipping unsupported geometry type at index 2504
# Skipping LineString with insufficient points at index 2506
# Skipping unsupported geometry type at index 2507
# Skipping LineString with insufficient points at index 2510
# Skipping unsupported geometry type at index 2511
# Skipping unsupported geometry type at index 2516
# Skipping unsupported geometry type at index 2517
# Skipping LineString with insufficient points at index 2518
# Skipping unsupported geometry type at index 2522
# Skipping unsupported geometry type at index 2543
# Skipping LineString with insufficient points at index 2545
# Skipping LineString with insufficient points at index 2566
# Skipping unsupported geometry type at index 2569
# Skipping LineString with insufficient points at index 2571
# Skipping LineString with insufficient points at index 2578
# Skipping LineString with insufficient points at index 2589
# Skipping LineString with insufficient points at index 2610
# Skipping LineString with insufficient points at index 2611
# Skipping unsupported geometry type at index 2613
# Skipping LineString with insufficient points at index 2614
# Skipping LineString with insufficient points at index 2618
# Skipping LineString with insufficient points at index 2642
# Skipping unsupported geometry type at index 2648
# Skipping LineString with insufficient points at index 2659
# Skipping unsupported geometry type at index 2663
# Skipping unsupported geometry type at index 2668
# Skipping LineString with insufficient points at index 2669
# Skipping unsupported geometry type at index 2670
# Skipping LineString with insufficient points at index 2672
# Skipping LineString with insufficient points at index 2673
# Skipping LineString with insufficient points at index 2674
# Skipping LineString with insufficient points at index 2685
# Skipping LineString with insufficient points at index 2693
# Skipping unsupported geometry type at index 2701
# Skipping LineString with insufficient points at index 2704
# Skipping LineString with insufficient points at index 2707
# Skipping unsupported geometry type at index 2715
# Skipping unsupported geometry type at index 2718
# Skipping unsupported geometry type at index 2723
# Skipping LineString with insufficient points at index 2730
# Skipping unsupported geometry type at index 2735
# Skipping LineString with insufficient points at index 2744
# Skipping LineString with insufficient points at index 2753
# Skipping unsupported geometry type at index 2755
# Skipping LineString with insufficient points at index 2756
# Skipping LineString with insufficient points at index 2762
# Skipping LineString with insufficient points at index 2763
# Skipping LineString with insufficient points at index 2773
# Skipping unsupported geometry type at index 2775
# Skipping unsupported geometry type at index 2776
# Skipping LineString with insufficient points at index 2791
# Skipping LineString with insufficient points at index 2794
# Skipping unsupported geometry type at index 2799
# Skipping LineString with insufficient points at index 2802
# Skipping LineString with insufficient points at index 2805
# Skipping unsupported geometry type at index 2824
# Skipping LineString with insufficient points at index 2825
# Skipping unsupported geometry type at index 2829
# Skipping unsupported geometry type at index 2831
# Skipping unsupported geometry type at index 2845
# Skipping LineString with insufficient points at index 2847
# Skipping LineString with insufficient points at index 2855
# Skipping unsupported geometry type at index 2856
# Skipping unsupported geometry type at index 2862
# Skipping LineString with insufficient points at index 2871
# Skipping unsupported geometry type at index 2882
# Skipping LineString with insufficient points at index 2900
# Skipping LineString with insufficient points at index 2901
# Skipping unsupported geometry type at index 2903
# Skipping LineString with insufficient points at index 2905
# Skipping LineString with insufficient points at index 2907
# Skipping LineString with insufficient points at index 2926
# Skipping unsupported geometry type at index 2929
# Skipping LineString with insufficient points at index 2931
# Skipping LineString with insufficient points at index 2940
# Skipping unsupported geometry type at index 2949
# Skipping LineString with insufficient points at index 2950
# Skipping unsupported geometry type at index 2957
# Skipping unsupported geometry type at index 2966
# Skipping LineString with insufficient points at index 2970
# Skipping LineString with insufficient points at index 2971
# Skipping LineString with insufficient points at index 2978
# Skipping unsupported geometry type at index 2979
# Skipping LineString with insufficient points at index 2980
# Skipping LineString with insufficient points at index 2981
# Skipping LineString with insufficient points at index 2985
# Skipping unsupported geometry type at index 2986
# Skipping unsupported geometry type at index 2989
# Skipping unsupported geometry type at index 3002
# Skipping LineString with insufficient points at index 3014
# Skipping LineString with insufficient points at index 3019
# Skipping unsupported geometry type at index 3021
# Skipping LineString with insufficient points at index 3028
# Skipping LineString with insufficient points at index 3031
# Skipping LineString with insufficient points at index 3034
# Skipping LineString with insufficient points at index 3036
# Skipping unsupported geometry type at index 3039
# Skipping unsupported geometry type at index 3042
# Skipping LineString with insufficient points at index 3046
# Skipping unsupported geometry type at index 3047
# Skipping LineString with insufficient points at index 3048
# Skipping LineString with insufficient points at index 3057
# Skipping unsupported geometry type at index 3058
# Skipping LineString with insufficient points at index 3061
# Skipping LineString with insufficient points at index 3064
# Skipping LineString with insufficient points at index 3065
# Skipping LineString with insufficient points at index 3075
# Skipping LineString with insufficient points at index 3084
# Skipping unsupported geometry type at index 3086
# Skipping unsupported geometry type at index 3090
# Skipping LineString with insufficient points at index 3091
# Skipping LineString with insufficient points at index 3092
# Skipping unsupported geometry type at index 3095
# Skipping LineString with insufficient points at index 3102
# Skipping LineString with insufficient points at index 3104
# Skipping LineString with insufficient points at index 3114
# Skipping unsupported geometry type at index 3119
# Skipping unsupported geometry type at index 3133
# Skipping LineString with insufficient points at index 3146
# Skipping unsupported geometry type at index 3153
# Skipping unsupported geometry type at index 3155
# Skipping LineString with insufficient points at index 3178
# Skipping LineString with insufficient points at index 3183
# Skipping unsupported geometry type at index 3184
# Skipping unsupported geometry type at index 3189
# Skipping LineString with insufficient points at index 3200
# Skipping LineString with insufficient points at index 3212
# Skipping unsupported geometry type at index 3221
# Skipping LineString with insufficient points at index 3240
# Skipping LineString with insufficient points at index 3249
# Skipping unsupported geometry type at index 3250
# Skipping LineString with insufficient points at index 3251
# Skipping unsupported geometry type at index 3255
# Skipping LineString with insufficient points at index 3259
# Skipping LineString with insufficient points at index 3263
# Skipping LineString with insufficient points at index 3275
# Skipping LineString with insufficient points at index 3279
# Skipping LineString with insufficient points at index 3281
# Skipping LineString with insufficient points at index 3282
# Skipping LineString with insufficient points at index 3295
# Skipping LineString with insufficient points at index 3297
# Skipping unsupported geometry type at index 3328
# Skipping LineString with insufficient points at index 3329
# Skipping LineString with insufficient points at index 3331
# Skipping LineString with insufficient points at index 3343
# Skipping LineString with insufficient points at index 3354
# Skipping LineString with insufficient points at index 3356
# Skipping unsupported geometry type at index 3357
# Skipping unsupported geometry type at index 3364
# Skipping LineString with insufficient points at index 3365
# Skipping unsupported geometry type at index 3368
# Skipping LineString with insufficient points at index 3369
# Skipping LineString with insufficient points at index 3372
# Skipping LineString with insufficient points at index 3384
# Skipping unsupported geometry type at index 3386
# Skipping unsupported geometry type at index 3387
# Skipping LineString with insufficient points at index 3390
# Skipping unsupported geometry type at index 3391
# Skipping unsupported geometry type at index 3392
# Skipping LineString with insufficient points at index 3399
# Skipping unsupported geometry type at index 3414
# Skipping unsupported geometry type at index 3415
# Skipping unsupported geometry type at index 3418
# Skipping LineString with insufficient points at index 3429
# Skipping LineString with insufficient points at index 3430
# Skipping unsupported geometry type at index 3431
# Skipping LineString with insufficient points at index 3435
# Skipping unsupported geometry type at index 3437
# Skipping unsupported geometry type at index 3440
# Skipping unsupported geometry type at index 3442
# Skipping unsupported geometry type at index 3443
# Skipping unsupported geometry type at index 3447
# Skipping unsupported geometry type at index 3451
# Skipping LineString with insufficient points at index 3453
# Skipping LineString with insufficient points at index 3457
# Skipping unsupported geometry type at index 3465
# Skipping LineString with insufficient points at index 3466
# Skipping LineString with insufficient points at index 3470
# Skipping unsupported geometry type at index 3473
# Skipping unsupported geometry type at index 3476
# Skipping LineString with insufficient points at index 3477
# Skipping unsupported geometry type at index 3482
# Skipping LineString with insufficient points at index 3490
# Skipping unsupported geometry type at index 3491
# Skipping LineString with insufficient points at index 3494
# Skipping LineString with insufficient points at index 3495
# Skipping unsupported geometry type at index 3497
# Skipping LineString with insufficient points at index 3498
# Skipping unsupported geometry type at index 3501
# Skipping unsupported geometry type at index 3504
# Skipping unsupported geometry type at index 3506
# Skipping unsupported geometry type at index 3507
# Skipping LineString with insufficient points at index 3508
# Skipping unsupported geometry type at index 3510
# Skipping LineString with insufficient points at index 3511
# Skipping LineString with insufficient points at index 3513
# Skipping unsupported geometry type at index 3514
# Skipping LineString with insufficient points at index 3518
# Skipping unsupported geometry type at index 3520
# Skipping unsupported geometry type at index 3526
# Skipping unsupported geometry type at index 3527
# Skipping unsupported geometry type at index 3529
# Skipping LineString with insufficient points at index 3530
# Skipping unsupported geometry type at index 3532
# Skipping LineString with insufficient points at index 3538
# Skipping LineString with insufficient points at index 3539
# Skipping unsupported geometry type at index 3540
# Skipping unsupported geometry type at index 3541
# Skipping LineString with insufficient points at index 3542
# Skipping unsupported geometry type at index 3549
# Skipping unsupported geometry type at index 3553
# ...
# Skipping LineString with insufficient points at index 5057
# Skipping LineString with insufficient points at index 5059
# Skipping LineString with insufficient points at index 5061
# Skipping LineString with insufficient points at index 5063
# Skipping LineString with insufficient points at index 5069
# Skipping unsupported geometry type at index 5073
# Skipping unsupported geometry type at index 5077
# Skipping unsupported geometry type at index 5085
# Skipping unsupported geometry type at index 5086
# Skipping LineString with insufficient points at index 5088
# Skipping unsupported geometry type at index 5095
# Skipping unsupported geometry type at index 5096
# Skipping unsupported geometry type at index 5099
# Skipping unsupported geometry type at index 5102
# Skipping LineString with insufficient points at index 5103
# Skipping LineString with insufficient points at index 5111
# Skipping unsupported geometry type at index 5112
# Skipping unsupported geometry type at index 5113
# Skipping unsupported geometry type at index 5115
# Skipping unsupported geometry type at index 5132
# Skipping LineString with insufficient points at index 5135
# Skipping unsupported geometry type at index 5136
# Skipping LineString with insufficient points at index 5137
# Skipping unsupported geometry type at index 5142
# Skipping unsupported geometry type at index 5143
# Skipping unsupported geometry type at index 5144
# Skipping unsupported geometry type at index 5145
# Skipping unsupported geometry type at index 5146
# Skipping unsupported geometry type at index 5148
# Skipping unsupported geometry type at index 5150
# Skipping unsupported geometry type at index 5166
# Skipping unsupported geometry type at index 5170
# Skipping LineString with insufficient points at index 5172
# Skipping LineString with insufficient points at index 5176
# Skipping unsupported geometry type at index 5180
# Skipping LineString with insufficient points at index 5183
# Skipping LineString with insufficient points at index 5186
# Skipping LineString with insufficient points at index 5192
# Skipping unsupported geometry type at index 5194
# Skipping unsupported geometry type at index 5196
# Skipping LineString with insufficient points at index 5198
# Skipping unsupported geometry type at index 5201
# Skipping LineString with insufficient points at index 5203
# Skipping LineString with insufficient points at index 5205
# Skipping unsupported geometry type at index 5209
# Skipping unsupported geometry type at index 5211
# Skipping LineString with insufficient points at index 5218
# Skipping unsupported geometry type at index 5220
# Skipping LineString with insufficient points at index 5221
# Skipping unsupported geometry type at index 5225
# Skipping LineString with insufficient points at index 5229
# Skipping unsupported geometry type at index 5234
# Skipping LineString with insufficient points at index 5235
# Skipping LineString with insufficient points at index 5239
# Skipping unsupported geometry type at index 5244
# Skipping unsupported geometry type at index 5245
# Skipping unsupported geometry type at index 5250
# Skipping unsupported geometry type at index 5254
# Skipping LineString with insufficient points at index 5258
# Skipping LineString with insufficient points at index 5261
# Skipping unsupported geometry type at index 5265
# Skipping unsupported geometry type at index 5266
# Skipping unsupported geometry type at index 5267
# Skipping LineString with insufficient points at index 5274
# Skipping LineString with insufficient points at index 5276
# Skipping LineString with insufficient points at index 5278
# Skipping LineString with insufficient points at index 5279
# Skipping unsupported geometry type at index 5280
# Skipping LineString with insufficient points at index 5286
# Skipping unsupported geometry type at index 5288
# Skipping unsupported geometry type at index 5290
# Skipping LineString with insufficient points at index 5296
# Skipping LineString with insufficient points at index 5300
# Skipping unsupported geometry type at index 5301
# Skipping unsupported geometry type at index 5304
# Skipping unsupported geometry type at index 5305
# Skipping unsupported geometry type at index 5311
# Skipping LineString with insufficient points at index 5312
# Skipping unsupported geometry type at index 5313
# Skipping unsupported geometry type at index 5314
# Skipping unsupported geometry type at index 5317
# Skipping unsupported geometry type at index 5319
# Skipping LineString with insufficient points at index 5328
# Skipping LineString with insufficient points at index 5329
# Skipping LineString with insufficient points at index 5331
# Skipping LineString with insufficient points at index 5333
# Skipping unsupported geometry type at index 5334
# Skipping LineString with insufficient points at index 5337
# Skipping LineString with insufficient points at index 5348
# Skipping unsupported geometry type at index 5355
# Skipping LineString with insufficient points at index 5358
# Skipping LineString with insufficient points at index 5359
# Skipping LineString with insufficient points at index 5361
# Skipping unsupported geometry type at index 5367
# Skipping LineString with insufficient points at index 5368
# Skipping LineString with insufficient points at index 5375
# Skipping unsupported geometry type at index 5376
# Skipping unsupported geometry type at index 5379
# Skipping LineString with insufficient points at index 5380
# Skipping unsupported geometry type at index 5382
# Skipping unsupported geometry type at index 5385
# Skipping unsupported geometry type at index 5390
# Skipping LineString with insufficient points at index 5396
# Skipping unsupported geometry type at index 5402
# Skipping unsupported geometry type at index 5404
# Skipping LineString with insufficient points at index 5406
# Skipping LineString with insufficient points at index 5408
# Skipping LineString with insufficient points at index 5410
# Skipping unsupported geometry type at index 5411
# Skipping unsupported geometry type at index 5412
# Skipping LineString with insufficient points at index 5418
# Skipping unsupported geometry type at index 5437
# Skipping LineString with insufficient points at index 5444
# Skipping LineString with insufficient points at index 5448
# Skipping unsupported geometry type at index 5450
# Skipping unsupported geometry type at index 5451
# Skipping LineString with insufficient points at index 5452
# Skipping unsupported geometry type at index 5453
# Skipping LineString with insufficient points at index 5455
# Skipping unsupported geometry type at index 5460
# Skipping LineString with insufficient points at index 5462
# Skipping LineString with insufficient points at index 5465
# Skipping unsupported geometry type at index 5466
# Skipping unsupported geometry type at index 5470
# Skipping unsupported geometry type at index 5474
# Skipping unsupported geometry type at index 5476
# Skipping unsupported geometry type at index 5477
# Skipping unsupported geometry type at index 5478
# Skipping unsupported geometry type at index 5480
# Skipping unsupported geometry type at index 5481
# Skipping LineString with insufficient points at index 5483
# Skipping LineString with insufficient points at index 5497
# Skipping unsupported geometry type at index 5503
# Skipping unsupported geometry type at index 5504
# Skipping LineString with insufficient points at index 5505
# Skipping LineString with insufficient points at index 5510
# Skipping LineString with insufficient points at index 5511
# Skipping unsupported geometry type at index 5514
# Skipping unsupported geometry type at index 5515
# Skipping unsupported geometry type at index 5520
# Skipping LineString with insufficient points at index 5522
# Skipping unsupported geometry type at index 5529
# Skipping LineString with insufficient points at index 5537
# Skipping unsupported geometry type at index 5542
# Skipping LineString with insufficient points at index 5544
# Skipping LineString with insufficient points at index 5545
# Skipping LineString with insufficient points at index 5546
# Skipping unsupported geometry type at index 5555
# Skipping unsupported geometry type at index 5558
# Skipping LineString with insufficient points at index 5568
# Skipping LineString with insufficient points at index 5569
# Skipping unsupported geometry type at index 5570
# Skipping LineString with insufficient points at index 5582
# Skipping LineString with insufficient points at index 5584
# Skipping unsupported geometry type at index 5590
# Skipping LineString with insufficient points at index 5593
# Skipping unsupported geometry type at index 5596
# Skipping unsupported geometry type at index 5599
# Skipping unsupported geometry type at index 5600
# Skipping unsupported geometry type at index 5601
# Skipping unsupported geometry type at index 5606
# Skipping unsupported geometry type at index 5607
# Skipping unsupported geometry type at index 5610
# Skipping unsupported geometry type at index 5616
# Skipping LineString with insufficient points at index 5617
# Skipping unsupported geometry type at index 5621
# Skipping unsupported geometry type at index 5622
# Skipping unsupported geometry type at index 5626
# Skipping unsupported geometry type at index 5629
# Skipping LineString with insufficient points at index 5634
# Skipping unsupported geometry type at index 5635
# Skipping unsupported geometry type at index 5636
# Skipping LineString with insufficient points at index 5641
# Skipping LineString with insufficient points at index 5645
# Skipping unsupported geometry type at index 5646
# Skipping unsupported geometry type at index 5650
# Skipping unsupported geometry type at index 5651
# Skipping unsupported geometry type at index 5653
# Skipping LineString with insufficient points at index 5657
# Skipping unsupported geometry type at index 5658
# Skipping LineString with insufficient points at index 5660
# Skipping unsupported geometry type at index 5661
# Skipping unsupported geometry type at index 5662
# Skipping unsupported geometry type at index 5671
# Skipping unsupported geometry type at index 5672
# Skipping LineString with insufficient points at index 5673
# Skipping unsupported geometry type at index 5684
# Skipping unsupported geometry type at index 5685
# Skipping unsupported geometry type at index 5688
# Skipping unsupported geometry type at index 5693
# Skipping LineString with insufficient points at index 5698
# Skipping unsupported geometry type at index 5699
# Skipping unsupported geometry type at index 5703
# Skipping unsupported geometry type at index 5704
# Skipping unsupported geometry type at index 5707
# Skipping LineString with insufficient points at index 5709
# Skipping LineString with insufficient points at index 5710
# Skipping LineString with insufficient points at index 5713
# Skipping unsupported geometry type at index 5714
# Skipping unsupported geometry type at index 5716
# Skipping unsupported geometry type at index 5717
# Skipping unsupported geometry type at index 5721
# Skipping LineString with insufficient points at index 5723
# Skipping unsupported geometry type at index 5724
# Skipping LineString with insufficient points at index 5728
# Skipping unsupported geometry type at index 5729
# Skipping unsupported geometry type at index 5730
# Skipping unsupported geometry type at index 5731
# Skipping LineString with insufficient points at index 5741
# Skipping unsupported geometry type at index 5742
# Skipping LineString with insufficient points at index 5744
# Skipping unsupported geometry type at index 5753
# Skipping unsupported geometry type at index 5759
# Skipping unsupported geometry type at index 5765
# Skipping LineString with insufficient points at index 5772
# Skipping unsupported geometry type at index 5773
# Skipping unsupported geometry type at index 5783
# Skipping unsupported geometry type at index 5787
# Skipping unsupported geometry type at index 5788
# Skipping unsupported geometry type at index 5793
# Skipping LineString with insufficient points at index 5800
# Skipping unsupported geometry type at index 5801
# Skipping unsupported geometry type at index 5808
# Skipping unsupported geometry type at index 5812
# Skipping LineString with insufficient points at index 5815
# Skipping LineString with insufficient points at index 5818
# Skipping unsupported geometry type at index 5823
# Skipping unsupported geometry type at index 5824
# Skipping LineString with insufficient points at index 5830
# Skipping unsupported geometry type at index 5831
# Skipping unsupported geometry type at index 5839
# Skipping unsupported geometry type at index 5853
# Skipping LineString with insufficient points at index 5854
# Skipping unsupported geometry type at index 5856
# Skipping unsupported geometry type at index 5859
# Skipping unsupported geometry type at index 5861
# Skipping unsupported geometry type at index 5863
# Skipping LineString with insufficient points at index 5868
# Skipping unsupported geometry type at index 5872
# Skipping LineString with insufficient points at index 5874
# Skipping LineString with insufficient points at index 5876
# Skipping LineString with insufficient points at index 5882
# Skipping unsupported geometry type at index 5884
# Skipping unsupported geometry type at index 5885
# Skipping unsupported geometry type at index 5886
# Skipping unsupported geometry type at index 5891
# Skipping LineString with insufficient points at index 5893
# Skipping unsupported geometry type at index 5894
# Skipping unsupported geometry type at index 5896
# Skipping LineString with insufficient points at index 5900
# Skipping unsupported geometry type at index 5901
# Skipping LineString with insufficient points at index 5905
# Skipping LineString with insufficient points at index 5906
# Skipping LineString with insufficient points at index 5912
# Skipping unsupported geometry type at index 5916
# Skipping unsupported geometry type at index 5917
# Skipping unsupported geometry type at index 5918
# Skipping unsupported geometry type at index 5921
# Skipping unsupported geometry type at index 5923
# Skipping unsupported geometry type at index 5926
# Skipping unsupported geometry type at index 5930
# Skipping unsupported geometry type at index 5931
# Skipping unsupported geometry type at index 5937
# Skipping LineString with insufficient points at index 5947
# Skipping LineString with insufficient points at index 5950
# Skipping LineString with insufficient points at index 5951
# Skipping LineString with insufficient points at index 5952
# Skipping LineString with insufficient points at index 5954
# Skipping unsupported geometry type at index 5959
# Skipping unsupported geometry type at index 5961
# Skipping LineString with insufficient points at index 5963
# Skipping unsupported geometry type at index 5964
# Skipping unsupported geometry type at index 5965
# Skipping unsupported geometry type at index 5966
# Skipping unsupported geometry type at index 5971
# Skipping LineString with insufficient points at index 5974
# Skipping unsupported geometry type at index 5977
# Skipping LineString with insufficient points at index 5978
# Skipping LineString with insufficient points at index 5979
# Skipping unsupported geometry type at index 5980
# Skipping LineString with insufficient points at index 5981
# Skipping unsupported geometry type at index 5982
# Skipping unsupported geometry type at index 5983
# Skipping LineString with insufficient points at index 5985
# Skipping unsupported geometry type at index 5987
# Skipping LineString with insufficient points at index 5988
# Skipping unsupported geometry type at index 5994
# Skipping LineString with insufficient points at index 6000
# Skipping LineString with insufficient points at index 6002
# Skipping unsupported geometry type at index 6005
# Skipping LineString with insufficient points at index 6006
# Skipping unsupported geometry type at index 6007
# Skipping unsupported geometry type at index 6010
# Skipping LineString with insufficient points at index 6013
# Skipping unsupported geometry type at index 6015
# Skipping LineString with insufficient points at index 6016
# Skipping unsupported geometry type at index 6017
# Skipping LineString with insufficient points at index 6018
# Skipping unsupported geometry type at index 6019
# Skipping LineString with insufficient points at index 6020
# Exported 4371 valid tree crowns to result/tree_crown_poly_smooth.shp

# %%
# Convert your DataFrame to a GeoDataFrame using the 'top_cor' column for geometry
# 'top_cor' is assumed to be a column containing geometries (e.g., points representing tree tops)
trees_gdf = gpd.GeoDataFrame(PC.trees, geometry='top_cor')

# Setting the Coordinate Reference System (CRS) for the GeoDataFrame
# EPSG:27700 corresponds to OSGB36 / British National Grid, which is commonly used in the UK
epsg_code = "EPSG:27700"
trees_gdf = trees_gdf.set_crs(epsg_code)

# Function to calculate the diameter of a tree crown polygon
def polygon_diameter(polygon):
    if isinstance(polygon, Polygon):
        # Extract the bounding box of the polygon (minx, miny, maxx, maxy)
        minx, miny, maxx, maxy = polygon.bounds
        # Calculate the diameter as the maximum of the width or height of the bounding box
        diameter = max(maxx - minx, maxy - miny)
        return diameter
    else:
        return None

# Calculate the diameter for each tree crown polygon
# 'crown_poly_raster' is assumed to be a column containing polygon geometries for tree crowns
trees_gdf['diameter'] = trees_gdf['crown_poly_raster'].apply(polygon_diameter)

# Create a DataFrame with tree number, height, and calculated diameter
trees_gdf['tree_number'] = trees_gdf.index  # Assign a unique tree number based on the index
tree_database = trees_gdf[['tree_number', 'top_height', 'diameter']].copy()

# Add the geometry column back to the new DataFrame to make it a GeoDataFrame
tree_database = gpd.GeoDataFrame(tree_database, geometry=trees_gdf.geometry)

# %%
# print(tree_database.head(10))
# Out:
#    tree_number  top_height  diameter                       geometry
# 0            0    1.483002       3.0  POINT (507631.500 246086.500)
# 1            1    1.958000       3.0  POINT (507629.500 246084.500)
# 2            2    2.009003       3.0  POINT (507627.500 246083.500)
# 3            3    1.918003       1.0  POINT (507626.500 246082.500)
# 4            4    2.667002       5.0  POINT (507623.500 246080.500)
# 5            5    2.211002       1.0  POINT (507619.500 246079.500)
# 6            6    1.929001       1.0  POINT (507618.500 246078.500)
# 7            7    1.359001       2.0  POINT (507597.500 246062.500)
# 8            8    3.320002       3.0  POINT (507485.500 245984.500)
# 9            9    3.936003       3.0  POINT (507484.500 245983.500)

# %%
# len(tree_database) # ensure that the number is the same as previously
# Out:
# 6021

# %%
import geopandas as gpd

# Load the shapefile of the planting areas
planting_areas_gdf = gpd.read_file('SS/Planting Types.shp')

# Perform a spatial join to keep only trees within the planting areas
# 'how="inner"' keeps only the rows where the spatial join condition ('within') is true
trees_within_planting_areas = gpd.sjoin(tree_database, planting_areas_gdf, how='inner', op='within')

# Remove the 'index_right' and 'id' columns if present
# This cleans up the GeoDataFrame by removing unnecessary columns resulting from the join
columns_to_drop = ['index_right', 'id']
trees_within_planting_areas = trees_within_planting_areas.drop(columns=[col for col in columns_to_drop if col in trees_within_planting_areas.columns])

# Load the shapefile containing information about planting years
planting_years_gdf = gpd.read_file('SS/Shocott Spring Area.shp')

# Perform a spatial join to add attributes from the planting years shapefile
# Again, 'how="inner"' ensures that only trees within the specified areas are kept
trees_within_both_areas = gpd.sjoin(trees_within_planting_areas, planting_years_gdf, how='inner', op='within')

# Clean up by removing any redundant columns from the second spatial join
columns_to_drop_second = ['index_right']  # Adjust based on actual column names resulting from the second join
trees_within_both_areas = trees_within_both_areas.drop(columns=[col for col in columns_to_drop_second if col in trees_within_both_areas.columns])

# Rename columns to provide meaningful names
# In this case, renaming 'id' (which might represent a planting year) to 'Year'
trees_within_both_areas = trees_within_both_areas.rename(columns={'id': 'Year'})

# %%
#len(trees_within_both_areas)
print(trees_within_both_areas.head(10))
# Out:
#     tree_number  top_height  diameter                       geometry  \
# 12           12    1.424002       1.0  POINT (507531.000 245983.000)
# 16           16    1.940001       1.0  POINT (507489.000 245960.000)
# 18           18    2.199003       1.0  POINT (507581.000 245946.000)
# 19           19    1.453003       1.0  POINT (507560.000 245938.000)
# 20           20    2.310001       1.0  POINT (507611.000 245938.000)
# 21           21    1.770002       1.0  POINT (507499.000 245930.000)
# 22           22    1.814003       1.0  POINT (507480.000 245914.000)
# 23           23    1.422001       1.0  POINT (507492.000 245911.000)
# 24           24    1.467001       1.0  POINT (507543.000 245908.000)
# 25           25    1.815001       1.0  POINT (507496.000 245890.000)
#
#           Type  year
# 12  Shrub-rich     3
# 16  Shrub-rich     3
# 18  Shrub-rich     3
# 19  Shrub-rich     3
# 20  Shrub-rich     3
# 21  Shrub-rich     3
# 22  Shrub-rich     3
# 23  Shrub-rich     3
# 24  Shrub-rich     3
# 25  Shrub-rich     3

# %%
# Create a CSV file for further analysis
trees_within_both_areas.to_csv('trees_within_both_areas.csv', index=False)

# %% [markdown]
# # Below section is based on Jucker et al. 2017 ("Allometric equations for integrating remote sensing imagery into forest monitoring programmes")

# %%
# Reading the CSV file into a DataFrame
df = pd.read_csv('trees_within_both_areas.csv')

# %%
# Parameters for DBH calculation
exp_factor_d = np.exp(0.056**2 / 2)

# Calculate DBH (Diameter at Breast Height)
df['DBH'] = 0.557 * (df['top_height'] * df['diameter'])**0.809 * exp_factor_d

# %%
# Parameters for AGB (Aboveground Biomass) calculation
exp_factor_agb = np.exp(0.204**2 / 2)

# As there is no option to classify the species of individual trees, 
# it will be assumed that each tree has an equal probability (50% chance) of being either an angiosperm or a gymnosperm.
# A weighted average will then be applied.

# Calculate AGB (Aboveground Biomass) for angiosperms
df['AGB_angiosperm'] = 0.016 * (df['top_height'] * df['diameter'])**2.013 * exp_factor_agb

# Calculate AGB (Aboveground Biomass) for gymnosperms
df['AGB_gymnosperm'] = 0.109 * (df['top_height'] * df['diameter'])**1.790 * exp_factor_agb

# %%
# Define the species mix proportions
species_mix_proportions = {
    "Mixed Wood": (0.4, 0.6),  # 40% Angiosperms, 60% Gymnosperms
    "Native Bro": (1.0, 0.0),  # 100% Angiosperms
    "Native Shr": (1.0, 0.0),  # 100% Angiosperms
    "Native Tim": (1.0, 0.0),  # 100% Angiosperms
    "Shrub-rich": (1.0, 0.0)   # 100% Angiosperms
}

# Function to calculate the total AGB for each tree based on the species mix
def calculate_agb_weighted(row):
    mix = row['Type']
    angiosperm_weight, gymnosperm_weight = species_mix_proportions.get(mix, (0, 0))
    return angiosperm_weight * row['AGB_angiosperm'] + gymnosperm_weight * row['AGB_gymnosperm']

# Apply the function to calculate the total AGB and store it in a new column 'AGB_total'
df['AGB_total'] = df.apply(calculate_agb_weighted, axis=1)

# %%
print(df.head)
# Out:
# <bound method NDFrame.head of       tree_number  top_height  diameter                   geometry  \
# 0              12    1.424002       1.0      POINT (507531 245983)
# 1              16    1.940001       1.0      POINT (507489 245960)
# 2              18    2.199003       1.0      POINT (507581 245946)
# 3              19    1.453003       1.0      POINT (507560 245938)
# 4              20    2.310001       1.0      POINT (507611 245938)
# ...           ...         ...       ...                        ...
# 5287         5817    3.610003       5.0  POINT (507902.5 245083.5)
# 5288         5866    1.633001       3.0      POINT (507868 245076)
# 5289         5889    1.717001       3.0      POINT (507881 245073)
# 5290         5964    2.130003       1.0  POINT (507875.5 245057.5)
# 5291         6002    2.775002       2.0  POINT (507881.5 245045.5)
#
#             Type  year       DBH  AGB_angiosperm  AGB_gymnosperm  \
# 0     Shrub-rich     3  0.742551        0.033279        0.209530
# 1     Shrub-rich     3  0.953604        0.062016        0.364442
# 2     Shrub-rich     3  1.055351        0.079810        0.456087
# 3     Shrub-rich     3  0.754762        0.034658        0.217230
# 4     Shrub-rich     3  1.098243        0.088127        0.498115
# ...          ...   ...       ...             ...             ...
# 5287  Native Bro     1  5.794640        5.526447       19.749588
# 5288  Native Bro     1  2.017592        0.400261        1.913182
# 5289  Native Bro     1  2.101148        0.442787        2.092906
# 5290  Native Bro     1  1.028480        0.074849        0.430788
# 5291  Native Bro     1  2.231873        0.514540        2.391928
#
#       AGB_weighted  AGB_total
# 0         0.139030   0.033279
# 1         0.243472   0.062016
# 2         0.305576   0.079810
# 3         0.144201   0.034658
# 4         0.334119   0.088127
# ...            ...        ...
# 5287     14.060331   5.526447
# 5288      1.308014   0.400261
# 5289      1.432858   0.442787
# 5290      0.288413   0.074849
# 5291      1.640973   0.514540
#
# [5292 rows x 11 columns]>

# %%
# Group the data by species mix ('Type') and calculate the sum of AGB and the number of trees
summary = df.groupby('Type').agg(
    total_AGB=('AGB_total', 'sum'),         # Sum of the total AGB for each species mix type
    number_of_trees=('tree_number', 'count') # Count of trees for each species mix type
).reset_index()

# Display the summary DataFrame
print(summary)
# Out:
#          Type     total_AGB  number_of_trees
# 0  Mixed Wood  35782.382699             4773
# 1  Native Bro    199.044372              269
# 2  Native Shr      8.723947               15
# 3  Native Tim     68.306814              184
# 4  Shrub-rich     24.464389               51

# %%
# Save the summary DataFrame to a CSV file
summary.to_csv('AGB_summary_by_species_mix.csv', index=False)i
